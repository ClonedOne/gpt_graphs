# %% [markdown]
# VADER	LEIA,R2-D2	C-3PO	OBI-WAN	LUKE	HAN,CHEWIE
# VADER	LEIA,R2-D2	C-3PO	OBI-WAN	LUKE	HAN,CHEWIE
# VADER	C-3PO	OBI-WAN	LUKE	HAN,CHEWIE	LEIA	R2-D2
# VADER	C-3PO	OBI-WAN	LUKE	HAN,CHEWIE	LEIA	R2-D2
# VADER	C-3PO	OBI-WAN	LUKE	HAN,CHEWIE	LEIA	R2-D2
# VADER	C-3PO	OBI-WAN	LUKE	HAN,CHEWIE	LEIA	R2-D2
# VADER	C-3PO	OBI-WAN	LUKE	HAN,CHEWIE	LEIA	R2-D2
# OBI-WAN	HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,LUKE
# OBI-WAN	HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,LUKE
# OBI-WAN	HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,LUKE
# OBI-WAN	HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,LUKE
# OBI-WAN	HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,LUKE
# HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE
# HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE
# HAN,CHEWIE	VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE
# VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE	HAN,CHEWIE
# VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE	HAN,CHEWIE
# VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE	HAN,CHEWIE
# VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE	HAN,CHEWIE
# VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE,HAN,CHEWIE
# VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE,HAN,CHEWIE
# VADER,LEIA	R2-D2,C-3PO,OBI-WAN,LUKE,HAN,CHEWIE
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER	LEIA,LUKE,HAN,CHEWIE	R2-D2,C-3PO	OBI-WAN
# VADER,OBI-WAN	LEIA,C-3PO,HAN,CHEWIE	R2-D2,LUKE
# VADER,OBI-WAN	LEIA,C-3PO,HAN,CHEWIE	R2-D2,LUKE
